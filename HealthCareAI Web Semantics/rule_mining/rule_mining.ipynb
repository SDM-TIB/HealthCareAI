# %% [markdown]
# AMIE: https://github.com/dig-team/amie
#     Using `amie3.jar` file to provide KG in the form of TSV file and generate rules (Y)
#
# SPaRKLE: https://github.com/SDM-TIB/SPARKLE/tree/main/AMIE_SPaRKLE
#     generating predictions of the rules (Y) using amie_sparkle.py
#     for generating the predictions just by modifying the input.json file you can execute amie_sparkle.py

# %% [markdown]
# # use AMIE to mine the rules and store into a database

# %%
import os
import subprocess

# Get the current directory where the notebook is running
current_dir = os.path.dirname(os.path.abspath('__file__'))

# Print current directory for debugging
print("Current directory:", current_dir)

# Construct the path to the .jar and .tsv files
jar_path = os.path.join(current_dir, 'amie-dev.jar')
tsv_path = os.path.join(current_dir, 'NSCLP.tsv')
# tsv_path = os.path.join(current_dir, 'french_training.tsv')

# Print paths to check correctness
print("Jar path:", jar_path)
print("TSV path:", tsv_path)

# Command to run the Java program
command = f'java -jar "{jar_path}" "{tsv_path}" -const'

# Use subprocess to run the command
process = subprocess.run(command, shell=True, text=True, capture_output=True)

# Print the output and error if any
print("Output:", process.stdout)
print("Error:", process.stderr)

rules = process.stdout
# Out:
# Current directory: /Users/jason/Documents/Coding Projects/KPI3/KDD HealthCareAI Extension/rule_mining
# Jar path: /Users/jason/Documents/Coding Projects/KPI3/KDD HealthCareAI Extension/rule_mining/amie-dev.jar
# TSV path: /Users/jason/Documents/Coding Projects/KPI3/KDD HealthCareAI Extension/rule_mining/NSCLP.tsv
# Output: Assuming rdf:type as type relation
# Loading files...
#   Starting NSCLP.tsv
#   Finished NSCLP.tsv, still running: 0
# Loaded 18715 facts in 0.20 s using -17 MB
# Using HeadCoverage as pruning metric with minimum threshold 0.01
# Using recursivity limit 3
# Lazy mining assistant that stops counting when the denominator gets too high
# No minimum threshold on standard confidence
# Filtering on PCA confidence with minimum threshold 0.1
# Constants in the arguments of relations are enabled
# Lossless (query refinement) heuristics enabled
# MRT calls: 0
# Starting the mining phase... Using 10 threads
# Rule	Head Coverage	Std Confidence	PCA Confidence	Positive Examples	Body size	PCA Body size	Functional variable
# ?a  smoking  NonSmoker   => ?a  age  YOUNGER	0.03580016	0.150055991	0.150055991	134	893	893	?a
# ?a  biomarker  ALK   => ?a  age  YOUNGER	0.022976222	0.297577855	0.297577855	86	289	289	?a
# ?a  biomarker  EGFR   => ?a  age  YOUNGER	0.032059845	0.120240481	0.120240481	120	998	998	?a
# ?a  gender  Female   => ?a  age  YOUNGER	0.060913706	0.13902439	0.13902439	228	1640	1640	?a
# ?a  age  YOUNGER   => ?a  smoking  NonSmoker	0.03580016	0.364130435	0.364130435	134	368	368	?a
# ?a  age  OLDER   => ?a  smoking  NonSmoker	0.20277852	0.224888889	0.224888889	759	3375	3375	?a
# ?a  gender  Male   => ?a  smoking  NonSmoker	0.056371894	0.100332858	0.100332858	211	2103	2103	?a
# ?a  gender  Female   => ?a  smoking  NonSmoker	0.182206786	0.415853659	0.415853659	682	1640	1640	?a
# ?a  hasCanceredFamily  Breast_Famale_2ndDegree   => ?a  smoking  NonSmoker	0.010152284	0.275362319	0.275362319	38	138	138	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  smoking  NonSmoker	0.01095378	0.238372093	0.238372093	41	172	172	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  smoking  NonSmoker	0.011220946	0.304347826	0.304347826	42	138	138	?a
# ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  smoking  NonSmoker	0.01095378	0.328	0.328	41	125	125	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  smoking  NonSmoker	0.014159765	0.294444444	0.294444444	53	180	180	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  smoking  NonSmoker	0.023777718	0.25648415	0.25648415	89	347	347	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  smoking  NonSmoker	0.018167246	0.158878505	0.158878505	68	428	428	?a
# ?a  biomarker  ALK   => ?a  smoking  NonSmoker	0.036601656	0.474048443	0.474048443	137	289	289	?a
# ?a  age  YOUNGER   => ?a  smoking  CurrentSmoker	0.031258349	0.317934783	0.317934783	117	368	368	?a
# ?a  hasCanceredFamily  Breast_Famale_2ndDegree   => ?a  smoking  CurrentSmoker	0.013358269	0.362318841	0.362318841	50	138	138	?a
# ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  smoking  CurrentSmoker	0.010152284	0.37254902	0.37254902	38	102	102	?a
# ?a  biomarker  EGFR   => ?a  smoking  NonSmoker	0.128773711	0.482965932	0.482965932	482	998	998	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  smoking  CurrentSmoker	0.015762757	0.327777778	0.327777778	59	180	180	?a
# ?a  hasCanceredFamily  Lung_Male_2ndDegree   => ?a  smoking  CurrentSmoker	0.017098584	0.438356164	0.438356164	64	146	146	?a
# ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  smoking  CurrentSmoker	0.011755277	0.47826087	0.47826087	44	92	92	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  smoking  CurrentSmoker	0.033930003	0.365994236	0.365994236	127	347	347	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  smoking  CurrentSmoker	0.01041945	0.317073171	0.317073171	39	123	123	?a
# ?a  gender  Female   => ?a  smoking  CurrentSmoker	0.132514026	0.302439024	0.302439024	496	1640	1640	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  smoking  CurrentSmoker	0.013358269	0.290697674	0.290697674	50	172	172	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  smoking  CurrentSmoker	0.011755277	0.31884058	0.31884058	44	138	138	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  smoking  CurrentSmoker	0.048356933	0.422897196	0.422897196	181	428	428	?a
# ?a  gender  Male   => ?a  smoking  CurrentSmoker	0.23109805	0.411317166	0.411317166	865	2103	2103	?a
# ?a  biomarker  ALK   => ?a  smoking  CurrentSmoker	0.014961261	0.193771626	0.193771626	56	289	289	?a
# ?a  age  OLDER   => ?a  smoking  CurrentSmoker	0.332353727	0.368592593	0.368592593	1244	3375	3375	?a
# ?a  age  YOUNGER   => ?a  smoking  PreviousSmoker	0.031258349	0.317934783	0.317934783	117	368	368	?a
# ?a  biomarker  KRAS   => ?a  smoking  CurrentSmoker	0.030724018	0.532407407	0.532407407	115	216	216	?a
# ?a  biomarker  EGFR   => ?a  smoking  CurrentSmoker	0.041143468	0.154308617	0.154308617	154	998	998	?a
# ?a  biomarker  PDL1   => ?a  smoking  CurrentSmoker	0.266631045	0.472985782	0.472985782	998	2110	2110	?a
# ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  smoking  PreviousSmoker	0.014961261	0.448	0.448	56	125	125	?a
# ?a  hasCanceredFamily  Breast_Famale_2ndDegree   => ?a  smoking  PreviousSmoker	0.013358269	0.362318841	0.362318841	50	138	138	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  smoking  PreviousSmoker	0.034998664	0.377521614	0.377521614	131	347	347	?a
# ?a  age  OLDER   => ?a  smoking  PreviousSmoker	0.366550895	0.406518519	0.406518519	1372	3375	3375	?a
# ?a  gender  Male   => ?a  smoking  PreviousSmoker	0.274378841	0.488349976	0.488349976	1027	2103	2103	?a
# ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  smoking  PreviousSmoker	0.011488111	0.421568627	0.421568627	43	102	102	?a
# ?a  gender  Female   => ?a  smoking  PreviousSmoker	0.123430403	0.281707317	0.281707317	462	1640	1640	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.047822602	0.418224299	0.418224299	179	428	428	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.014694096	0.447154472	0.447154472	55	123	123	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.021640395	0.470930233	0.470930233	81	172	172	?a
# ?a  hasCanceredFamily  Lung_Famale_1stDegree   => ?a  smoking  PreviousSmoker	0.01041945	0.375	0.375	39	104	104	?a
# ?a  hasCanceredFamily  Lung_Male_2ndDegree   => ?a  smoking  PreviousSmoker	0.012823938	0.328767123	0.328767123	48	146	146	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.018167246	0.377777778	0.377777778	68	180	180	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.0138926	0.376811594	0.376811594	52	138	138	?a
# ?a  biomarker  ALK   => ?a  smoking  PreviousSmoker	0.025647876	0.332179931	0.332179931	96	289	289	?a
# ?a  biomarker  KRAS   => ?a  smoking  PreviousSmoker	0.024579215	0.425925926	0.425925926	92	216	216	?a
# ?a  biomarker  PDL1   => ?a  smoking  PreviousSmoker	0.241250334	0.427962085	0.427962085	903	2110	2110	?a
# ?a  biomarker  EGFR   => ?a  smoking  PreviousSmoker	0.096713866	0.362725451	0.362725451	362	998	998	?a
# ?a  age  YOUNGER   => ?a  gender  Male	0.037403153	0.380434783	0.380434783	140	368	368	?a
# ?a  age  OLDER   => ?a  gender  Male	0.524445632	0.58162963	0.58162963	1963	3375	3375	?a
# ?a  smoking  NonSmoker   => ?a  gender  Male	0.056371894	0.236282195	0.236282195	211	893	893	?a
# ?a  smoking  PreviousSmoker   => ?a  gender  Male	0.274378841	0.689724647	0.689724647	1027	1489	1489	?a
# ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  gender  Male	0.019235907	0.576	0.576	72	125	125	?a
# ?a  smoking  CurrentSmoker   => ?a  gender  Male	0.23109805	0.635562087	0.635562087	865	1361	1361	?a
# ?a  hasCanceredFamily  Breast_Famale_2ndDegree   => ?a  gender  Male	0.01095378	0.297101449	0.297101449	41	138	138	?a
# ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  gender  Male	0.017098584	0.62745098	0.62745098	64	102	102	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  gender  Male	0.053433075	0.576368876	0.576368876	200	347	347	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  gender  Male	0.029388191	0.611111111	0.611111111	110	180	180	?a
# ?a  hasCanceredFamily  Lung_Male_2ndDegree   => ?a  gender  Male	0.019770238	0.506849315	0.506849315	74	146	146	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  gender  Male	0.018701576	0.569105691	0.569105691	70	123	123	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  gender  Male	0.022976222	0.623188406	0.623188406	86	138	138	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  gender  Male	0.02831953	0.61627907	0.61627907	106	172	172	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  gender  Male	0.076142132	0.66588785	0.66588785	285	428	428	?a
# ?a  hasCanceredFamily  Lung_Famale_1stDegree   => ?a  gender  Male	0.014694096	0.528846154	0.528846154	55	104	104	?a
# ?a  hasCanceredFamily  Esophagogastric_Famale_1stDegree   => ?a  gender  Male	0.012022442	0.616438356	0.616438356	45	73	73	?a
# ?a  hasCanceredFamily  Uterus/cervical_Famale_1stDegree   => ?a  gender  Male	0.01095378	0.493975904	0.493975904	41	83	83	?a
# ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  gender  Male	0.016029923	0.652173913	0.652173913	60	92	92	?a
# ?a  biomarker  KRAS   => ?a  gender  Male	0.039006145	0.675925926	0.675925926	146	216	216	?a
# ?a  age  YOUNGER   => ?a  gender  Female	0.060913706	0.619565217	0.619565217	228	368	368	?a
# ?a  biomarker  EGFR   => ?a  gender  Male	0.097782527	0.366733467	0.366733467	366	998	998	?a
# ?a  biomarker  ALK   => ?a  gender  Male	0.030189687	0.39100346	0.39100346	113	289	289	?a
# ?a  biomarker  BRAF   => ?a  gender  Male	0.01095378	0.803921569	0.803921569	41	51	51	?a
# ?a  smoking  NonSmoker   => ?a  gender  Female	0.182206786	0.763717805	0.763717805	682	893	893	?a
# ?a  age  OLDER   => ?a  gender  Female	0.37723751	0.41837037	0.41837037	1412	3375	3375	?a
# ?a  smoking  CurrentSmoker   => ?a  gender  Female	0.132514026	0.364437913	0.364437913	496	1361	1361	?a
# ?a  biomarker  PDL1   => ?a  gender  Male	0.374298691	0.663981043	0.663981043	1401	2110	2110	?a
# ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  gender  Female	0.014159765	0.424	0.424	53	125	125	?a
# ?a  hasCanceredFamily  Breast_Famale_2ndDegree   => ?a  gender  Female	0.025915041	0.702898551	0.702898551	97	138	138	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  gender  Female	0.038204649	0.33411215	0.33411215	143	428	428	?a
# ?a  smoking  PreviousSmoker   => ?a  gender  Female	0.123430403	0.310275353	0.310275353	462	1489	1489	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  gender  Female	0.018701576	0.388888889	0.388888889	70	180	180	?a
# ?a  hasCanceredFamily  Lung_Male_2ndDegree   => ?a  gender  Female	0.019235907	0.493150685	0.493150685	72	146	146	?a
# ?a  hasCanceredFamily  Lung_Famale_1stDegree   => ?a  gender  Female	0.013091103	0.471153846	0.471153846	49	104	104	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  gender  Female	0.0138926	0.376811594	0.376811594	52	138	138	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  gender  Female	0.014159765	0.430894309	0.430894309	53	123	123	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  gender  Female	0.03927331	0.423631124	0.423631124	147	347	347	?a
# ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  gender  Female	0.010152284	0.37254902	0.37254902	38	102	102	?a
# ?a  biomarker  ALK   => ?a  gender  Female	0.047021106	0.60899654	0.60899654	176	289	289	?a
# ?a  hasCanceredFamily  Uterus/cervical_Famale_1stDegree   => ?a  gender  Female	0.011220946	0.506024096	0.506024096	42	83	83	?a
# ?a  biomarker  EGFR   => ?a  gender  Female	0.168848517	0.633266533	0.633266533	632	998	998	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  gender  Female	0.017632915	0.38372093	0.38372093	66	172	172	?a
# ?a  biomarker  KRAS   => ?a  gender  Female	0.018701576	0.324074074	0.324074074	70	216	216	?a
# ?a  biomarker  PDL1   => ?a  gender  Female	0.189420251	0.336018957	0.336018957	709	2110	2110	?a
# ?a  gender  Female   => ?a  age  OLDER	0.37723751	0.86097561	0.86097561	1412	1640	1640	?a
# ?a  gender  Male   => ?a  age  OLDER	0.524445632	0.933428436	0.933428436	1963	2103	2103	?a
# ?a  hasCanceredFamily  Leukemia_Famale_1stDegree   => ?a  age  OLDER	0.015495592	1	1	58	58	58	?a
# ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  age  OLDER	0.03232701	0.968	0.968	121	125	125	?a
# ?a  smoking  PreviousSmoker   => ?a  age  OLDER	0.366550895	0.921423774	0.921423774	1372	1489	1489	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  age  OLDER	0.087897408	0.948126801	0.948126801	329	347	347	?a
# ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  age  OLDER	0.025113545	0.921568627	0.921568627	94	102	102	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  age  OLDER	0.107934812	0.943925234	0.943925234	404	428	428	?a
# ?a  hasCanceredFamily  Breast_Famale_2ndDegree   => ?a  age  OLDER	0.02831953	0.768115942	0.768115942	106	138	138	?a
# ?a  smoking  CurrentSmoker   => ?a  age  OLDER	0.332353727	0.914033799	0.914033799	1244	1361	1361	?a
# ?a  smoking  NonSmoker   => ?a  age  OLDER	0.20277852	0.849944009	0.849944009	759	893	893	?a
# ?a  hasCanceredFamily  Liver_Male_1stDegree   => ?a  age  OLDER	0.0138926	0.945454545	0.945454545	52	55	55	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  age  OLDER	0.032594176	0.991869919	0.991869919	122	123	123	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  age  OLDER	0.041410633	0.901162791	0.901162791	155	172	172	?a
# ?a  hasCanceredFamily  Colorrectal_Famale_2ndDegree   => ?a  age  OLDER	0.010152284	0.826086957	0.826086957	38	46	46	?a
# ?a  hasCanceredFamily  Lung_Famale_1stDegree   => ?a  age  OLDER	0.026449372	0.951923077	0.951923077	99	104	104	?a
# ?a  hasCanceredFamily  Breast_Famale_3rdDegree   => ?a  age  OLDER	0.010686615	0.754716981	0.754716981	40	53	53	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  age  OLDER	0.034998664	0.949275362	0.949275362	131	138	138	?a
# ?a  hasCanceredFamily  Esophagogastric_Famale_2ndDegree   => ?a  age  OLDER	0.010152284	0.926829268	0.926829268	38	41	41	?a
# ?a  hasCanceredFamily  Leukemia_Male_1stDegree   => ?a  age  OLDER	0.013091103	1	1	49	49	49	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  age  OLDER	0.045685279	0.95	0.95	171	180	180	?a
# ?a  hasCanceredFamily  Esophagogastric_Famale_1stDegree   => ?a  age  OLDER	0.018968742	0.97260274	0.97260274	71	73	73	?a
# ?a  hasCanceredFamily  Pancreatic_Male_1stDegree   => ?a  age  OLDER	0.01095378	0.931818182	0.931818182	41	44	44	?a
# ?a  hasCanceredFamily  Bladder/urinary_tract_Male_1stDegree   => ?a  age  OLDER	0.013091103	0.960784314	0.960784314	49	51	51	?a
# ?a  hasCanceredFamily  Uterus/cervical_Famale_1stDegree   => ?a  age  OLDER	0.020037403	0.903614458	0.903614458	75	83	83	?a
# ?a  biomarker  ROS1   => ?a  age  OLDER	0.013091103	0.942307692	0.942307692	49	52	52	?a
# ?a  biomarker  BRAF   => ?a  age  OLDER	0.012556773	0.921568627	0.921568627	47	51	51	?a
# ?a  biomarker  EGFR   => ?a  age  OLDER	0.2345712	0.879759519	0.879759519	878	998	998	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_2ndDegree   => ?a  age  OLDER	0.012556773	0.810344828	0.810344828	47	58	58	?a
# ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  age  OLDER	0.022976222	0.934782609	0.934782609	86	92	92	?a
# ?a  biomarker  ALK   => ?a  age  OLDER	0.054234571	0.702422145	0.702422145	203	289	289	?a
# ?a  biomarker  PDL1   => ?a  age  OLDER	0.524712797	0.930805687	0.930805687	1964	2110	2110	?a
# ?a  hasCanceredFamily  Lung_Male_2ndDegree   => ?a  age  OLDER	0.030991184	0.794520548	0.794520548	116	146	146	?a
# ?a  biomarker  KRAS   => ?a  age  OLDER	0.055837563	0.967592593	0.967592593	209	216	216	?a
# ?a  age  OLDER   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.107934812	0.119703704	0.119703704	404	3375	3375	?a
# ?a  smoking  CurrentSmoker   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.048356933	0.132990448	0.132990448	181	1361	1361	?a
# ?a  biomarker  PDL1   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.073470478	0.130331754	0.130331754	275	2110	2110	?a
# ?a  smoking  PreviousSmoker   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.047822602	0.120214909	0.120214909	179	1489	1489	?a
# ?a  gender  Male   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.076142132	0.135520685	0.135520685	285	2103	2103	?a
# ?a  age  YOUNGER   => ?a  biomarker  ALK	0.022976222	0.233695652	0.233695652	86	368	368	?a
# ?a  smoking  NonSmoker   => ?a  biomarker  ALK	0.036601656	0.153415454	0.153415454	137	893	893	?a
# ?a  gender  Female   => ?a  biomarker  ALK	0.047021106	0.107317073	0.107317073	176	1640	1640	?a
# ?a  age  OLDER   => ?a  biomarker  EGFR	0.2345712	0.260148148	0.260148148	878	3375	3375	?a
# ?a  smoking  CurrentSmoker   => ?a  biomarker  EGFR	0.041143468	0.113152094	0.113152094	154	1361	1361	?a
# ?a  gender  Female   => ?a  biomarker  EGFR	0.168848517	0.385365854	0.385365854	632	1640	1640	?a
# ?a  smoking  NonSmoker   => ?a  biomarker  EGFR	0.128773711	0.539753639	0.539753639	482	893	893	?a
# ?a  gender  Male   => ?a  biomarker  EGFR	0.097782527	0.17403709	0.17403709	366	2103	2103	?a
# ?a  age  YOUNGER   => ?a  biomarker  EGFR	0.032059845	0.326086957	0.326086957	120	368	368	?a
# ?a  smoking  PreviousSmoker   => ?a  biomarker  EGFR	0.096713866	0.243116185	0.243116185	362	1489	1489	?a
# ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  biomarker  EGFR	0.010152284	0.304	0.304	38	125	125	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  biomarker  EGFR	0.0138926	0.302325581	0.302325581	52	172	172	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  biomarker  EGFR	0.010152284	0.275362319	0.275362319	38	138	138	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  biomarker  EGFR	0.025113545	0.270893372	0.270893372	94	347	347	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  biomarker  EGFR	0.023777718	0.207943925	0.207943925	89	428	428	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  biomarker  EGFR	0.016029923	0.333333333	0.333333333	60	180	180	?a
# ?a  age  YOUNGER   => ?a  biomarker  PDL1	0.039006145	0.39673913	0.39673913	146	368	368	?a
# ?a  smoking  NonSmoker   => ?a  biomarker  PDL1	0.055837563	0.234042553	0.234042553	209	893	893	?a
# ?a  smoking  CurrentSmoker   => ?a  biomarker  PDL1	0.266631045	0.73328435	0.73328435	998	1361	1361	?a
# ?a  hasCanceredFamily  Breast_Famale_2ndDegree   => ?a  biomarker  PDL1	0.018434411	0.5	0.5	69	138	138	?a
# ?a  gender  Female   => ?a  biomarker  PDL1	0.189420251	0.432317073	0.432317073	709	1640	1640	?a
# ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  biomarker  PDL1	0.016831419	0.504	0.504	63	125	125	?a
# ?a  smoking  PreviousSmoker   => ?a  biomarker  PDL1	0.241250334	0.60644728	0.60644728	903	1489	1489	?a
# ?a  age  OLDER   => ?a  biomarker  PDL1	0.524712797	0.581925926	0.581925926	1964	3375	3375	?a
# ?a  gender  Male   => ?a  biomarker  PDL1	0.374298691	0.666191155	0.666191155	1401	2103	2103	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  biomarker  PDL1	0.025113545	0.546511628	0.546511628	94	172	172	?a
# ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  biomarker  PDL1	0.015762757	0.578431373	0.578431373	59	102	102	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  biomarker  PDL1	0.020838899	0.565217391	0.565217391	78	138	138	?a
# ?a  hasCanceredFamily  Lung_Famale_1stDegree   => ?a  biomarker  PDL1	0.015495592	0.557692308	0.557692308	58	104	104	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  biomarker  PDL1	0.020304569	0.617886179	0.617886179	76	123	123	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  biomarker  PDL1	0.073470478	0.642523364	0.642523364	275	428	428	?a
# ?a  hasCanceredFamily  Esophagogastric_Famale_1stDegree   => ?a  biomarker  PDL1	0.01041945	0.534246575	0.534246575	39	73	73	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  biomarker  PDL1	0.025113545	0.522222222	0.522222222	94	180	180	?a
# ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  biomarker  PDL1	0.017365749	0.706521739	0.706521739	65	92	92	?a
# ?a  hasCanceredFamily  Uterus/cervical_Famale_1stDegree   => ?a  biomarker  PDL1	0.011488111	0.518072289	0.518072289	43	83	83	?a
# ?a  hasCanceredFamily  Lung_Male_2ndDegree   => ?a  biomarker  PDL1	0.022441892	0.575342466	0.575342466	84	146	146	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  biomarker  PDL1	0.053433075	0.576368876	0.576368876	200	347	347	?a
# ?a  gender  Female  ?a  smoking  PreviousSmoker   => ?a  age  YOUNGER	0.018434411	0.149350649	0.149350649	69	462	462	?a
# ?a  biomarker  ALK  ?a  gender  Female   => ?a  age  YOUNGER	0.017098584	0.363636364	0.363636364	64	176	176	?a
# ?a  gender  Male  ?a  smoking  NonSmoker   => ?a  age  YOUNGER	0.010152284	0.180094787	0.180094787	38	211	211	?a
# ?a  biomarker  ALK  ?a  smoking  NonSmoker   => ?a  age  YOUNGER	0.01095378	0.299270073	0.299270073	41	137	137	?a
# ?a  biomarker  EGFR  ?a  gender  Male   => ?a  age  YOUNGER	0.012289607	0.12568306	0.12568306	46	366	366	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  smoking  NonSmoker	0.013625434	0.298245614	0.298245614	51	171	171	?a
# ?a  age  YOUNGER  ?a  gender  Female   => ?a  smoking  NonSmoker	0.025647876	0.421052632	0.421052632	96	228	228	?a
# ?a  age  YOUNGER  ?a  biomarker  ALK   => ?a  smoking  NonSmoker	0.01095378	0.476744186	0.476744186	41	86	86	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  smoking  NonSmoker	0.01095378	0.338842975	0.338842975	41	121	121	?a
# ?a  gender  Female  ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  smoking  NonSmoker	0.010686615	0.571428571	0.571428571	40	70	70	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  smoking  NonSmoker	0.010686615	0.305343511	0.305343511	40	131	131	?a
# ?a  biomarker  ALK  ?a  gender  Female   => ?a  smoking  NonSmoker	0.028586695	0.607954545	0.607954545	107	176	176	?a
# ?a  age  OLDER  ?a  biomarker  EGFR   => ?a  smoking  NonSmoker	0.113545285	0.48405467	0.48405467	425	878	878	?a
# ?a  gender  Female  ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  smoking  NonSmoker	0.017632915	0.448979592	0.448979592	66	147	147	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Lung_Male_2ndDegree   => ?a  smoking  CurrentSmoker	0.012289607	0.547619048	0.547619048	46	84	84	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Breast_Famale_2ndDegree   => ?a  smoking  CurrentSmoker	0.010686615	0.579710145	0.579710145	40	69	69	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Breast_Famale_2ndDegree   => ?a  smoking  CurrentSmoker	0.011220946	0.396226415	0.396226415	42	106	106	?a
# ?a  biomarker  EGFR  ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  smoking  NonSmoker	0.012556773	0.5	0.5	47	94	94	?a
# ?a  biomarker  EGFR  ?a  gender  Female   => ?a  smoking  NonSmoker	0.102324339	0.606012658	0.606012658	383	632	632	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  smoking  CurrentSmoker	0.022441892	0.42	0.42	84	200	200	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  smoking  CurrentSmoker	0.011488111	0.5	0.5	43	86	86	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  smoking  CurrentSmoker	0.035532995	0.466666667	0.466666667	133	285	285	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  smoking  CurrentSmoker	0.012022442	0.478723404	0.478723404	45	94	94	?a
# ?a  biomarker  PDL1  ?a  gender  Female   => ?a  smoking  CurrentSmoker	0.093240716	0.492242595	0.492242595	349	709	709	?a
# ?a  age  OLDER  ?a  biomarker  KRAS   => ?a  smoking  CurrentSmoker	0.030189687	0.540669856	0.540669856	113	209	209	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  smoking  PreviousSmoker	0.012022442	0.625	0.625	45	72	72	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  smoking  CurrentSmoker	0.036601656	0.498181818	0.498181818	137	275	275	?a
# ?a  age  OLDER  ?a  biomarker  PDL1   => ?a  smoking  CurrentSmoker	0.24899813	0.474541752	0.474541752	932	1964	1964	?a
# ?a  age  OLDER  ?a  gender  Male   => ?a  smoking  CurrentSmoker	0.216671119	0.413143148	0.413143148	811	1963	1963	?a
# ?a  biomarker  KRAS  ?a  gender  Male   => ?a  smoking  CurrentSmoker	0.022174726	0.568493151	0.568493151	83	146	146	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.045952445	0.425742574	0.425742574	172	404	404	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.020037403	0.483870968	0.483870968	75	155	155	?a
# ?a  age  OLDER  ?a  gender  Male   => ?a  smoking  PreviousSmoker	0.261554902	0.498726439	0.498726439	979	1963	1963	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.012022442	0.523255814	0.523255814	45	86	86	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  smoking  PreviousSmoker	0.011488111	0.457446809	0.457446809	43	94	94	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.014694096	0.450819672	0.450819672	55	122	122	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.011488111	0.614285714	0.614285714	43	70	70	?a
# ?a  biomarker  ALK  ?a  gender  Male   => ?a  smoking  PreviousSmoker	0.015228426	0.504424779	0.504424779	57	113	113	?a
# ?a  biomarker  PDL1  ?a  gender  Male   => ?a  smoking  PreviousSmoker	0.187015763	0.499643112	0.499643112	700	1401	1401	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.010152284	0.5	0.5	38	76	76	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.01095378	0.436170213	0.436170213	41	94	94	?a
# ?a  biomarker  EGFR  ?a  gender  Male   => ?a  smoking  PreviousSmoker	0.04969276	0.508196721	0.508196721	186	366	366	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.037403153	0.49122807	0.49122807	140	285	285	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.015228426	0.518181818	0.518181818	57	110	110	?a
# ?a  age  YOUNGER  ?a  biomarker  EGFR   => ?a  gender  Male	0.012289607	0.383333333	0.383333333	46	120	120	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.016831419	0.594339623	0.594339623	63	106	106	?a
# ?a  age  OLDER  ?a  biomarker  PDL1   => ?a  smoking  PreviousSmoker	0.228159231	0.434826884	0.434826884	854	1964	1964	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.03179268	0.432727273	0.432727273	119	275	275	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  gender  Male	0.051562917	0.58662614	0.58662614	193	329	329	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  smoking  PreviousSmoker	0.013625434	0.542553191	0.542553191	51	94	94	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  gender  Male	0.016564253	0.659574468	0.659574468	62	94	94	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  gender  Male	0.026983703	0.651612903	0.651612903	101	155	155	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  gender  Male	0.074004809	0.685643564	0.685643564	277	404	404	?a
# ?a  age  OLDER  ?a  smoking  PreviousSmoker   => ?a  gender  Male	0.261554902	0.713556851	0.713556851	979	1372	1372	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  gender  Male	0.015228426	0.662790698	0.662790698	57	86	86	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Esophagogastric_Famale_1stDegree   => ?a  gender  Male	0.012022442	0.633802817	0.633802817	45	71	71	?a
# ?a  age  OLDER  ?a  smoking  CurrentSmoker   => ?a  gender  Male	0.216671119	0.65192926	0.65192926	811	1244	1244	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree  ?a  smoking  PreviousSmoker   => ?a  gender  Male	0.02484638	0.709923664	0.709923664	93	131	131	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  gender  Male	0.016831419	0.777777778	0.777777778	63	81	81	?a
# ?a  age  OLDER  ?a  biomarker  KRAS   => ?a  gender  Male	0.038471814	0.688995215	0.688995215	144	209	209	?a
# ?a  age  OLDER  ?a  biomarker  PDL1   => ?a  gender  Male	0.356932941	0.680244399	0.680244399	1336	1964	1964	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  gender  Male	0.037403153	0.782122905	0.782122905	140	179	179	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  gender  Male	0.011488111	0.781818182	0.781818182	43	55	55	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  gender  Male	0.012022442	0.865384615	0.865384615	45	52	52	?a
# ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree  ?a  smoking  PreviousSmoker   => ?a  gender  Male	0.012022442	0.803571429	0.803571429	45	56	56	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  gender  Male	0.015228426	0.838235294	0.838235294	57	68	68	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree  ?a  smoking  CurrentSmoker   => ?a  gender  Male	0.010686615	0.677966102	0.677966102	40	59	59	?a
# ?a  biomarker  PDL1  ?a  smoking  PreviousSmoker   => ?a  gender  Male	0.187015763	0.775193798	0.775193798	700	903	903	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  gender  Male	0.012556773	0.746031746	0.746031746	47	63	63	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree  ?a  smoking  CurrentSmoker   => ?a  gender  Male	0.022441892	0.661417323	0.661417323	84	127	127	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree  ?a  smoking  CurrentSmoker   => ?a  gender  Male	0.010152284	0.76	0.76	38	50	50	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  gender  Male	0.019503072	0.776595745	0.776595745	73	94	94	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  gender  Male	0.01790008	0.712765957	0.712765957	67	94	94	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  gender  Male	0.01095378	0.694915254	0.694915254	41	59	59	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree  ?a  smoking  CurrentSmoker   => ?a  gender  Male	0.035532995	0.73480663	0.73480663	133	181	181	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  gender  Male	0.016297088	0.782051282	0.782051282	61	78	78	?a
# ?a  biomarker  KRAS  ?a  smoking  CurrentSmoker   => ?a  gender  Male	0.022174726	0.72173913	0.72173913	83	115	115	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  gender  Male	0.012823938	0.738461538	0.738461538	48	65	65	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  gender  Male	0.055570398	0.756363636	0.756363636	208	275	275	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree  ?a  smoking  NonSmoker   => ?a  gender  Female	0.014961261	0.823529412	0.823529412	56	68	68	?a
# ?a  biomarker  ALK  ?a  smoking  NonSmoker   => ?a  gender  Female	0.028586695	0.781021898	0.781021898	107	137	137	?a
# ?a  biomarker  EGFR  ?a  smoking  NonSmoker   => ?a  gender  Female	0.102324339	0.794605809	0.794605809	383	482	482	?a
# ?a  age  OLDER  ?a  smoking  NonSmoker   => ?a  gender  Female	0.15655891	0.772068511	0.772068511	586	759	759	?a
# ?a  age  YOUNGER  ?a  biomarker  ALK   => ?a  gender  Female	0.017098584	0.744186047	0.744186047	64	86	86	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  gender  Female	0.014159765	0.438016529	0.438016529	53	121	121	?a
# ?a  gender  Female  ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  age  OLDER	0.014159765	1	1	53	53	53	?a
# ?a  age  OLDER  ?a  biomarker  EGFR   => ?a  gender  Female	0.149078279	0.635535308	0.635535308	558	878	878	?a
# ?a  gender  Female  ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  age  OLDER	0.013625434	0.980769231	0.980769231	51	52	52	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  age  OLDER	0.051562917	0.965	0.965	193	200	200	?a
# ?a  gender  Female  ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  age  OLDER	0.018167246	0.971428571	0.971428571	68	70	70	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  age  OLDER	0.016564253	0.96875	0.96875	62	64	64	?a
# ?a  gender  Male  ?a  smoking  CurrentSmoker   => ?a  age  OLDER	0.216671119	0.937572254	0.937572254	811	865	865	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  age  OLDER	0.026983703	0.952830189	0.952830189	101	106	106	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  age  OLDER	0.074004809	0.971929825	0.971929825	277	285	285	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  age  OLDER	0.015228426	0.95	0.95	57	60	60	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  age  OLDER	0.018701576	1	1	70	70	70	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Lung_Famale_1stDegree   => ?a  age  OLDER	0.014159765	0.963636364	0.963636364	53	55	55	?a
# ?a  biomarker  EGFR  ?a  gender  Female   => ?a  age  OLDER	0.149078279	0.882911392	0.882911392	558	632	632	?a
# ?a  gender  Male  ?a  smoking  PreviousSmoker   => ?a  age  OLDER	0.261554902	0.953261928	0.953261928	979	1027	1027	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree   => ?a  age  OLDER	0.016297088	0.968253968	0.968253968	61	63	63	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree  ?a  smoking  PreviousSmoker   => ?a  age  OLDER	0.033662837	0.961832061	0.961832061	126	131	131	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Esophagogastric_Famale_1stDegree   => ?a  age  OLDER	0.012022442	1	1	45	45	45	?a
# ?a  biomarker  KRAS  ?a  gender  Male   => ?a  age  OLDER	0.038471814	0.98630137	0.98630137	144	146	146	?a
# ?a  hasCanceredFamily  Colorrectal_Famale_1stDegree  ?a  smoking  NonSmoker   => ?a  age  OLDER	0.01095378	1	1	41	41	41	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  age  OLDER	0.045952445	0.960893855	0.960893855	172	179	179	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  age  OLDER	0.020037403	0.925925926	0.925925926	75	81	81	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  age  OLDER	0.014694096	1	1	55	55	55	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Uterus/cervical_Famale_1stDegree   => ?a  age  OLDER	0.010686615	0.975609756	0.975609756	40	41	41	?a
# ?a  biomarker  PDL1  ?a  smoking  PreviousSmoker   => ?a  age  OLDER	0.228159231	0.945736434	0.945736434	854	903	903	?a
# ?a  hasCanceredFamily  Other_Famale_1stDegree  ?a  smoking  PreviousSmoker   => ?a  age  OLDER	0.011488111	1	1	43	43	43	?a
# ?a  biomarker  PDL1  ?a  gender  Male   => ?a  age  OLDER	0.356932941	0.953604568	0.953604568	1336	1401	1401	?a
# ?a  hasCanceredFamily  Lung_Famale_1stDegree  ?a  smoking  PreviousSmoker   => ?a  age  OLDER	0.010152284	0.974358974	0.974358974	38	39	39	?a
# ?a  hasCanceredFamily  Other_Male_1stDegree  ?a  smoking  CurrentSmoker   => ?a  age  OLDER	0.011488111	0.977272727	0.977272727	43	44	44	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree  ?a  smoking  CurrentSmoker   => ?a  age  OLDER	0.011220946	0.954545455	0.954545455	42	44	44	?a
# ?a  biomarker  PDL1  ?a  smoking  CurrentSmoker   => ?a  age  OLDER	0.24899813	0.933867735	0.933867735	932	998	998	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree  ?a  smoking  CurrentSmoker   => ?a  age  OLDER	0.01041945	1	1	39	39	39	?a
# ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree  ?a  smoking  NonSmoker   => ?a  age  OLDER	0.010686615	0.952380952	0.952380952	40	42	42	?a
# ?a  biomarker  KRAS  ?a  smoking  CurrentSmoker   => ?a  age  OLDER	0.030189687	0.982608696	0.982608696	113	115	115	?a
# ?a  biomarker  EGFR  ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  age  OLDER	0.024312049	0.968085106	0.968085106	91	94	94	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  age  OLDER	0.050761421	0.95	0.95	190	200	200	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  age  OLDER	0.014694096	0.93220339	0.93220339	55	59	59	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree  ?a  smoking  NonSmoker   => ?a  age  OLDER	0.013625434	0.962264151	0.962264151	51	53	53	?a
# ?a  biomarker  EGFR  ?a  smoking  NonSmoker   => ?a  age  OLDER	0.113545285	0.881742739	0.881742739	425	482	482	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  age  OLDER	0.069730163	0.949090909	0.949090909	261	275	275	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  age  OLDER	0.020304569	1	1	76	76	76	?a
# ?a  biomarker  EGFR  ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  age  OLDER	0.012556773	0.903846154	0.903846154	47	52	52	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Esophagogastric_Famale_1stDegree   => ?a  age  OLDER	0.01041945	1	1	39	39	39	?a
# ?a  biomarker  EGFR  ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  age  OLDER	0.015495592	0.966666667	0.966666667	58	60	60	?a
# ?a  biomarker  PDL1  ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  age  OLDER	0.016297088	0.938461538	0.938461538	61	65	65	?a
# ?a  age  OLDER  ?a  smoking  PreviousSmoker   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.045952445	0.125364431	0.125364431	172	1372	1372	?a
# ?a  age  OLDER  ?a  smoking  CurrentSmoker   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.044883783	0.135048232	0.135048232	168	1244	1244	?a
# ?a  age  OLDER  ?a  gender  Male   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.074004809	0.141110545	0.141110545	277	1963	1963	?a
# ?a  age  OLDER  ?a  biomarker  PDL1   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.069730163	0.132892057	0.132892057	261	1964	1964	?a
# ?a  age  OLDER  ?a  smoking  NonSmoker   => ?a  hasCanceredFamily  Breast_Famale_1stDegree	0.022441892	0.110671937	0.110671937	84	759	759	?a
# ?a  age  OLDER  ?a  biomarker  EGFR   => ?a  hasCanceredFamily  Breast_Famale_1stDegree	0.024312049	0.103644647	0.103644647	91	878	878	?a
# ?a  biomarker  PDL1  ?a  smoking  CurrentSmoker   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.036601656	0.137274549	0.137274549	137	998	998	?a
# ?a  gender  Male  ?a  smoking  CurrentSmoker   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.035532995	0.153757225	0.153757225	133	865	865	?a
# ?a  biomarker  PDL1  ?a  gender  Male   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.055570398	0.148465382	0.148465382	208	1401	1401	?a
# ?a  biomarker  PDL1  ?a  smoking  PreviousSmoker   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.03179268	0.131782946	0.131782946	119	903	903	?a
# ?a  age  YOUNGER  ?a  smoking  NonSmoker   => ?a  biomarker  ALK	0.01095378	0.305970149	0.305970149	41	134	134	?a
# ?a  gender  Male  ?a  smoking  PreviousSmoker   => ?a  hasCanceredFamily  Lung_Male_1stDegree	0.037403153	0.136319377	0.136319377	140	1027	1027	?a
# ?a  age  YOUNGER  ?a  gender  Female   => ?a  biomarker  ALK	0.017098584	0.280701754	0.280701754	64	228	228	?a
# ?a  gender  Female  ?a  smoking  NonSmoker   => ?a  biomarker  ALK	0.028586695	0.156891496	0.156891496	107	682	682	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  biomarker  EGFR	0.012556773	0.303225806	0.303225806	47	155	155	?a
# ?a  age  OLDER  ?a  smoking  NonSmoker   => ?a  biomarker  EGFR	0.113545285	0.559947299	0.559947299	425	759	759	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  biomarker  EGFR	0.024312049	0.276595745	0.276595745	91	329	329	?a
# ?a  age  OLDER  ?a  gender  Female   => ?a  biomarker  EGFR	0.149078279	0.395184136	0.395184136	558	1412	1412	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Prostate_Male_1stDegree   => ?a  biomarker  EGFR	0.015495592	0.339181287	0.339181287	58	171	171	?a
# ?a  gender  Female  ?a  hasCanceredFamily  Breast_Famale_1stDegree   => ?a  biomarker  EGFR	0.015495592	0.394557823	0.394557823	58	147	147	?a
# ?a  age  YOUNGER  ?a  gender  Male   => ?a  biomarker  EGFR	0.012289607	0.328571429	0.328571429	46	140	140	?a
# ?a  gender  Female  ?a  smoking  NonSmoker   => ?a  biomarker  EGFR	0.102324339	0.561583578	0.561583578	383	682	682	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree  ?a  smoking  NonSmoker   => ?a  biomarker  EGFR	0.01041945	0.573529412	0.573529412	39	68	68	?a
# ?a  gender  Male  ?a  smoking  CurrentSmoker   => ?a  biomarker  PDL1	0.173390329	0.750289017	0.750289017	649	865	865	?a
# ?a  age  OLDER  ?a  smoking  CurrentSmoker   => ?a  biomarker  PDL1	0.24899813	0.749196141	0.749196141	932	1244	1244	?a
# ?a  hasCanceredFamily  Breast_Famale_2ndDegree  ?a  smoking  CurrentSmoker   => ?a  biomarker  PDL1	0.010686615	0.8	0.8	40	50	50	?a
# ?a  hasCanceredFamily  Prostate_Male_1stDegree  ?a  smoking  CurrentSmoker   => ?a  biomarker  PDL1	0.012022442	0.762711864	0.762711864	45	59	59	?a
# ?a  hasCanceredFamily  Breast_Famale_1stDegree  ?a  smoking  PreviousSmoker   => ?a  biomarker  PDL1	0.022174726	0.633587786	0.633587786	83	131	131	?a
# ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  biomarker  PDL1	0.010152284	0.690909091	0.690909091	38	55	55	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree  ?a  smoking  CurrentSmoker   => ?a  biomarker  PDL1	0.036601656	0.756906077	0.756906077	137	181	181	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  biomarker  PDL1	0.020304569	0.62295082	0.62295082	76	122	122	?a
# ?a  hasCanceredFamily  Lung_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  biomarker  PDL1	0.03179268	0.664804469	0.664804469	119	179	179	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  biomarker  PDL1	0.069730163	0.646039604	0.646039604	261	404	404	?a
# ?a  age  OLDER  ?a  gender  Male   => ?a  biomarker  PDL1	0.356932941	0.680590932	0.680590932	1336	1963	1963	?a
# ?a  age  OLDER  ?a  smoking  PreviousSmoker   => ?a  biomarker  PDL1	0.228159231	0.62244898	0.62244898	854	1372	1372	?a
# ?a  gender  Male  ?a  smoking  PreviousSmoker   => ?a  biomarker  PDL1	0.187015763	0.681596884	0.681596884	700	1027	1027	?a
# ?a  hasCanceredFamily  Colorrectal_Male_1stDegree  ?a  smoking  PreviousSmoker   => ?a  biomarker  PDL1	0.013625434	0.62962963	0.62962963	51	81	81	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Lung_Male_2ndDegree   => ?a  biomarker  PDL1	0.018701576	0.603448276	0.603448276	70	116	116	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Other_Famale_1stDegree   => ?a  biomarker  PDL1	0.014694096	0.585106383	0.585106383	55	94	94	?a
# ?a  age  OLDER  ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  biomarker  PDL1	0.016297088	0.709302326	0.709302326	61	86	86	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Other_Male_1stDegree   => ?a  biomarker  PDL1	0.012823938	0.8	0.8	48	60	60	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Lung_Male_1stDegree   => ?a  biomarker  PDL1	0.055570398	0.729824561	0.729824561	208	285	285	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Colorrectal_Male_1stDegree   => ?a  biomarker  PDL1	0.019503072	0.688679245	0.688679245	73	106	106	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Esophagogastric_Male_1stDegree   => ?a  biomarker  PDL1	0.013358269	0.714285714	0.714285714	50	70	70	?a
# ?a  gender  Male  ?a  hasCanceredFamily  Head_and_neck_Male_1stDegree   => ?a  biomarker  PDL1	0.016297088	0.709302326	0.709302326	61	86	86	?a
# Mining done in 6.54 s
# Total time 6.84 s
# 349 rules mined.
#
# Error: Using the default schema relations

# %%
rest = []
start_line = False

for l in rules.split('\n'):
    if l.startswith('Rule'):
        start_line = True
        rest.append(l)
        continue
    if l.startswith("Mining done"):
        start_line = False
    if start_line:
        if l.startswith('?'):
            rest.append(l)
# rest
# print(len(rest))

# %%
import mysql.connector
import pandas as pd

def create_mysql_database(text_list, db_name, table_name, user, password, host='localhost'):
    # Extract the header (first line) and the data (remaining lines)
    header = text_list[0].split("\t")
    data = [line.split("\t") for line in text_list[1:]]

    # Create a pandas DataFrame for easier handling
    df = pd.DataFrame(data, columns=header)
    # Split the "Rule" column into "Body" and "Head"
    df[['Body', 'Head']] = df['Rule'].str.split(' => ', expand=True)
    df = df[['Rule', 'Body', 'Head'] + [col for col in df.columns if col not in ['Rule', 'Body', 'Head']]]

    header += ['Body', 'Head']
    # Convert appropriate columns to float and int
    df[header[1]] = df[header[1]].astype(float)  # Head Coverage
    df[header[2]] = df[header[2]].astype(float)  # Std Confidence
    df[header[3]] = df[header[3]].astype(float)  # PCA Confidence
    df[header[4]] = df[header[4]].astype(int)    # Positive Examples
    df[header[5]] = df[header[5]].astype(int)    # Body size
    df[header[6]] = df[header[6]].astype(int)    # PCA Body size

    # Connect to the MySQL server
    conn = mysql.connector.connect(
        host=host,
        user=user,
        password=password
    )
    cursor = conn.cursor()

    # Create the database if it doesn't exist
    cursor.execute(f"CREATE DATABASE IF NOT EXISTS {db_name}")
    cursor.execute(f"USE {db_name}")

    # Create the table with the appropriate column names and types
    columns = [
        '`Rule` VARCHAR(1024)',           # Rule (text)
        '`Body` VARCHAR(1024)',            # Body (text)
        "`Head` VARCHAR(255)",              # Head (text)
        '`Head Coverage` FLOAT',         # Head Coverage (float)
        '`Std Confidence` FLOAT',        # Std Confidence (float)
        '`PCA Confidence` FLOAT',        # PCA Confidence (float)
        '`Positive Examples` INT',       # Positive Examples (int)
        '`Body size` INT',               # Body size (int)
        '`PCA Body size` INT',           # PCA Body size (int)
        '`Functional variable` VARCHAR(255)'  # Functional variable (text)
    ]
    # print(f'CREATE TABLE IF NOT EXISTS {table_name} ({", ".join(columns)})')
    cursor.execute(f'DROP TABLE IF EXISTS {table_name}')
    cursor.execute(f'CREATE TABLE {table_name} ({", ".join(columns)})')

    # Insert the data into the table
    for i, row in df.iterrows():
        cursor.execute(
            f'INSERT INTO {table_name} VALUES ({", ".join(["%s"] * len(header))})', 
            tuple(row)
        )
        if i % 1000 == 0:
            print(i)

    # Commit the changes and close the connection
    conn.commit()
    cursor.close()
    conn.close()

    print(f"MySQL database {db_name} with table {table_name} created successfully.")


create_mysql_database(
    text_list=rest, 
    db_name='rules_db', 
    table_name='rules_table_syn', 
    user='root', 
    password='admin123'
)
# Out:
# 0
# MySQL database rules_db with table rules_table_syn created successfully.

# %% [markdown]
# ```SELECT Body, Head, `PCA Confidence`, `Head Coverage`
# FROM rules_table
# ORDER BY `PCA Confidence` DESC, `Head Coverage` DESC```
#
#
# ```
# SELECT Body, Head, `PCA Confidence`, `Head Coverage`
# FROM rules_table
# WHERE Head like "%Relapse%"
# ORDER BY (`PCA Confidence` ) DESC
# ```

# %% [markdown]
# # Query rules with PCA higher than a threshold

# %%
import mysql.connector
import csv

def query_rules_to_csv(db_name, table_name, user, password, csv_file, PCA_threshold=0.5, host='localhost'):
    try:
        # Connect to the MySQL server
        conn = mysql.connector.connect(
            host=host,
            user=user,
            password=password,
            database=db_name
        )
        cursor = conn.cursor()

        # SQL query to fetch rules
        query = f"""SELECT * FROM {table_name} WHERE `PCA Confidence` >= {PCA_threshold} 
        AND `PCA Confidence` < 1.0 
        AND 
        (   (Head not like '%vocab/age%' 
            AND Head not like '%vocab/hasSmokingHabit%' 
            AND Head not like '%vocab/sex%'
            AND Head not like '%vocab/hasStage%'
            AND Head not like '%vocab/locatedInHospital%'
            AND Head not like '%vocab/hasProgressionRelapse%')
            OR (Head LIKE '%vocab/hasProgressionRelapse  Progression%' AND Body LIKE "%vocab/hasStage%" ) 
            OR (Head LIKE '%vocab/hasProgressionRelapse  Relapse%')
        )
        """
        # AND Head not like '%vocab/hasProgressionRelapse  Progression%'  
        """
        If remove the Progression, we have much less patients in KG':  
        1837 -> 1221 
        """ 
        cursor.execute(query)

        # Fetch all rows
        rows = cursor.fetchall()

        # Fetch column names
        column_names = [i[0] for i in cursor.description]

        # Write the result to a CSV file
        with open(csv_file, 'w', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            
            # Write the column headers
            writer.writerow(column_names)
            
            # Write the data rows
            writer.writerows(rows)

        # Close the cursor and connection
        cursor.close()
        conn.close()

        print(f"Data successfully written to {csv_file}")

    except mysql.connector.Error as err:
        print(f"Error: {err}")

# Example usage
query_rules_to_csv(
    db_name='rules_db',
    table_name='rules_table_syn',
    user='root',
    password='admin123',
    csv_file='rules_NSCLP.csv',
    PCA_threshold=0.5 
)
# Out:
# Data successfully written to rules_NSCLP.csv

# %% [markdown]
# # Query Rules with PCA Confidence = 1.0 as knowledge for GPT4

# %%
import mysql.connector
import csv
import re

family_mapping = {
        "UNK": "UNK", "Father": "M1", "Mother": "F1", "Brother": "M1", "Sister": "F1",
        "Daughter": "F1", "Son": "M1", "Uncle": "M2", "Nephew": "M2", "Grandfather": "M2",
        "Grandmother": "F2", "Aunt": "F2", "Niece": "F2", "Granddaughter": "F2", "Grandson": "M2",
        "Grandgrandfather": "M3", "Grandgrandmother": "F3", "No": "No", "Halfsister": "F2",
        "Halfbrother": "M2", "Female_Cousin": "F3", "Male_Cousin": "M3", "NULL": "NULL", 
        'Granduncle': "M4", 'Greatgrandfather': "M4", 'Greatgrandmother':"F4"}


def transform_line(line):
    # Regex to capture the necessary parts of the line wherever they occur
    pattern = r"(\?a\s+hasFamilyCancerType\s+)(\w+)&(\w+)"
    
    # Function to replace the matched part with the new triple format
    def repl(match):
        subject = "?a"                     # the subject identifier
        family = match.group(2)            # "Brother", "Sister", etc.
        cancer = match.group(3)            # "Prostate", "Lung", etc.

        # Creating the new format: adding a new triple for familyGender
        family_gender = "Male" if "M" in family_mapping[family] else "Female"
        new_triples = f"{subject} familyGender {family_gender} {subject} hasFamilyCancerType {cancer}"
        return new_triples
    
    # Apply the regex substitution
    transformed_line = re.sub(pattern, repl, line)
    return transformed_line


def translate(rule:str):
    translate_dict = {
    "age": "whose age is {}",
    "hasEpisodeType": "whose treatment episode type is {}",
    "hasBio": "who has positive biomarker test result on {}",
    "hasFamilyCancerType": "who has at least one {} that has {} cancer",
    "hasSmokingHabit": "who is a {},",
    "locatedInHospital": "who went to a hospital located in {}",
    "hasProgressionRelapse": "whose cancer has {}",
    "sex": "who is a {}",
    "hasStage": "who is in stage {}"
    }

    rule = rule.replace("http://research.tib.eu/clarify2020/vocab/", "").replace("http://research.tib.eu/clarify2020/entity/", "")
    rule = transform_line(rule)
    return rule
    

def query_rules_to_csv(db_name, table_name, user, password, csv_file, PCA_threshold=0.6, host='localhost'):
    try:
        # Connect to the MySQL server
        conn = mysql.connector.connect(
            host=host,
            user=user,
            password=password,
            database=db_name
        )
        cursor = conn.cursor()

        # SQL query to fetch rules
        query = f"""SELECT Rule FROM {table_name} where 
        `PCA Confidence` >= 0.8 
        AND Head NOT LIKE "%age%"
        AND Head NOT LIKE "%gender%"
        """

        # query = f"""SELECT Rule, `PCA Confidence` FROM {table_name} where 
        # `PCA Confidence` >= 0.95 
        # AND Rule NOT LIKE "%vocab/hasDrugSchema%"
        # AND Rule NOT LIKE "%vocab/hasComorbidity%"
        # AND Rule NOT LIKE "%vocab/hasPreviousCancerType%"
        # AND Rule NOT LIKE "%vocab/hasPreviousCancerType%"
        # AND Rule NOT LIKE "%vocab/hasEpisodeType%"
        # AND Rule NOT LIKE "%vocab/hasRace%"
        # AND Rule NOT LIKE "%vocab/hasProgressionRelapse%"
        # AND Rule NOT LIKE "%vocab/locatedInHospital%"
        # AND Rule NOT LIKE "%vocab/hasStage%" """
        # AND Head not like '%vocab/hasProgressionRelapse  Progression%'  
        """
        If remove the Progression, we have much less patients in KG':  
        1837 -> 1221 
        """ 
        cursor.execute(query)

        # Fetch all rows
        rows = cursor.fetchall()
        rows = [(translate(row[0]),) for row in rows]
        
        # Fetch column names
        column_names = [i[0] for i in cursor.description]

        # Write the result to a CSV file
        with open(csv_file, 'w', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            
            # Write the column headers
            writer.writerow(column_names)
            
            # Write the data rows
            writer.writerows(rows)

        # Close the cursor and connection
        cursor.close()
        conn.close()

        print(f"Data successfully written to {csv_file}")

    except mysql.connector.Error as err:
        print(f"Error: {err}")

# Example usage
query_rules_to_csv(
    db_name='rules_db',
    table_name='rules_table_syn',
    user='root',
    password='admin123',
    csv_file='rules_NSCLP_PCA=1.0.csv',
    PCA_threshold=1.0 
)
# Out:
# Data successfully written to rules_NSCLP_PCA=1.0.csv

# %% [markdown]
# # Abundant

# %%
import re

def transform_line(line):
    # Regex to capture the necessary parts of the line wherever they occur
    pattern = r"(\?a\s+hasFamilyCancerType\s+)(\w+)&(\w+)"
    
    # Function to replace the matched part with the new triple format
    def repl(match):
        subject = "?a"                     # the subject identifier
        family = match.group(2)            # "Brother", "Sister", etc.
        cancer = match.group(3)            # "Prostate", "Lung", etc.

        # Creating the new format: adding a new triple for familyGender
        new_triples = f"{subject} familyGender {family} {subject} hasFamilyCancerType {cancer}"
        return new_triples
    
    # Apply the regex substitution
    transformed_line = re.sub(pattern, repl, line)
    return transformed_line

# Example usage:
for input_line in """?a  hasFamilyCancerType  Brother&Prostate   => ?a  hasProgressionRelapse  Progression
# ?a  hasFamilyCancerType  Sister&Lung   => ?a  hasProgressionRelapse  Progression
# ?a  hasFamilyCancerType  Brother&Head_and_neck   => ?a  hasProgressionRelapse  Progression
# ?a  hasFamilyCancerType  Brother&Esophagogastric   => ?a  hasProgressionRelapse  Progression
""".split("\n"):
# input_line = "?a  hasFamilyCancerType  Brother&Prostate   => ?a  hasProgressionRelapse  Progression"
    print(transform_line(input_line))
# Out:
# ?a familyGender Brother ?a hasFamilyCancerType Prostate   => ?a  hasProgressionRelapse  Progression
# ?a familyGender Sister ?a hasFamilyCancerType Lung   => ?a  hasProgressionRelapse  Progression
# ?a familyGender Brother ?a hasFamilyCancerType Head_and_neck   => ?a  hasProgressionRelapse  Progression
# ?a familyGender Brother ?a hasFamilyCancerType Esophagogastric   => ?a  hasProgressionRelapse  Progression
